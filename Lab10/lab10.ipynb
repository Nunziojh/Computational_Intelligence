# %% [markdown]
# Nunzio Messineo - Computational Intelligence - 2023/2024
# https://github.com/Nunziojh/Computational_Intelligence/

# %% [markdown]
# # LAB10
#
# Use reinforcement learning to devise a tic-tac-toe player.
#
# ### Deadlines:
#
# * Submission: [Dies Natalis Solis Invicti](https://en.wikipedia.org/wiki/Sol_Invictus)
# * Reviews: [Befana](https://en.wikipedia.org/wiki/Befana)

# %%
import numpy as np
import random
import copy
import hashlib

# %%
class TicTacToe:
    def __init__(self):
        self.board = np.full((3, 3), '.')  
        self.player_mark = 'X'
        self.opponent_mark = 'O'
        self.winner = None
        self.game_over = False

    def reset(self):
        self.board = np.full((3, 3), '.')  
        self.winner = None
        self.game_over = False

    def get_state(self):
        return tuple(map(tuple, self.board))

    def is_valid_move(self, action):
        return self.board[action] == '.'
    
    def make_move(self, action):
        if self.is_valid_move(action) and not self.game_over:
            self.board[action] = self.player_mark
            self.check_winner()
            self.player_mark, self.opponent_mark = self.opponent_mark, self.player_mark
            return True
        return False

    def check_winner(self):
        # Check rows, columns, and diagonals for a winner
        for i in range(3):
            if np.all(self.board[i, :] == self.player_mark) or np.all(self.board[:, i] == self.player_mark):
                self.winner = self.player_mark
                self.game_over = True
                return
        if np.all(np.diag(self.board) == self.player_mark) or np.all(np.diag(np.fliplr(self.board)) == self.player_mark):
            self.winner = self.player_mark
            self.game_over = True
            return
        if '.' not in self.board:
            # If the board is full and no winner, it's a tie
            self.game_over = True
            return

# %%
class QLearningAgent:
    def __init__(self, epsilon=0.05, alpha=0.5, gamma=0.9):
        self.epsilon = epsilon # exploration rate
        self.alpha = alpha # learning rate
        self.gamma = gamma # discount factor
        self.q_values = {} #quality values

    #def get_q_value(self, state, action):
        # Get the current Q-value for the given state-action pair       
    #    return self.q_values.get((hash(str(state)), action), 0.0)

    def get_q_value(self, state, action):
        state_hash = hashlib.sha256(str(state).encode()).hexdigest()
        return self.q_values.get((state_hash, action), np.random.rand() * 0.01)

    def choose_action(self, state, valid_actions):
        if np.random.rand() < self.epsilon:
            # exploration
            return np.random.choice(valid_actions)
        else:
            # exploitation
            q_values = [self.get_q_value(state, action) for action in valid_actions]
            return valid_actions[np.argmax(q_values)]

    def update_q_value(self, state, action, reward, next_state):
        flat_next_state = np.ravel(next_state)
        best_next_action = max([(self.get_q_value(flat_next_state, a), a) for a in range(9) if flat_next_state[a] == 0], default=(0, 0))[1]
        new_q_value = reward + self.gamma * self.get_q_value(next_state, best_next_action)
        self.q_values[(state, action)] = (1 - self.alpha) * self.get_q_value(state, action) + self.alpha * new_q_value

# %%
def play_game(agent, env):
    env.reset()
    state = env.get_state()
    total_reward = 0

    while not env.game_over:
        valid_actions = [i for i in range(9) if env.is_valid_move((i // 3, i % 3))]
        action = agent.choose_action(state, valid_actions)
        env.make_move((action // 3, action % 3))
        next_state = env.get_state()

        reward = 0

        if env.game_over:
            if env.winner == env.player_mark :
                reward = 1.0  # 1 for a win
            elif env.winner == env.opponent_mark:
                reward = -0.5 # -1 for a loss
            else:
                reward = 0  # 0 for a tie

        agent.update_q_value(state, action, reward, next_state)
        state = next_state
        total_reward += reward

    return total_reward

# %%
# Training the agent
agent = QLearningAgent()
total_reward = 0 

for episode in range(500_000):
    env = TicTacToe()
    total_reward += play_game(agent, env)

    if episode % 1000 == 0:
        print(f"Episode: {episode}, Total Reward: {total_reward}")

# Test the trained agent
for _ in range(5):
    test_env = TicTacToe()
    state = test_env.get_state()

    while not test_env.game_over:
        print(f"Current State:\n{np.array(state)}")
        action = agent.choose_action(state, [i for i in range(9) if test_env.is_valid_move((i // 3, i % 3))])
        test_env.make_move((action // 3, action % 3))
        state = test_env.get_state()
    
    #for key, value in agent.q_values.items():
    #   print(f"Q-value for {key}: {value}")

    print(f"Game Over. Winner: {test_env.winner}")
    print(np.array(state))
    print(" - - - - - - - - - - - ")
# Out:
# Episode: 0, Total Reward: -0.5
# Episode: 1000, Total Reward: -431.0
# Episode: 2000, Total Reward: -866.5
# Episode: 3000, Total Reward: -1304.0
# Episode: 4000, Total Reward: -1738.0
# Episode: 5000, Total Reward: -2177.0
# Episode: 6000, Total Reward: -2620.0
# Episode: 7000, Total Reward: -3058.5
# Episode: 8000, Total Reward: -3507.0
# Episode: 9000, Total Reward: -3946.0
# Episode: 10000, Total Reward: -4381.5
# Episode: 11000, Total Reward: -4825.0
# Episode: 12000, Total Reward: -5266.5
# Episode: 13000, Total Reward: -5704.5
# Episode: 14000, Total Reward: -6146.5
# Episode: 15000, Total Reward: -6592.0
# Episode: 16000, Total Reward: -7020.0
# Episode: 17000, Total Reward: -7461.5
# Episode: 18000, Total Reward: -7888.0
# Episode: 19000, Total Reward: -8327.5
# Episode: 20000, Total Reward: -8766.5
# Episode: 21000, Total Reward: -9195.0
# Episode: 22000, Total Reward: -9636.0
# Episode: 23000, Total Reward: -10063.5
# Episode: 24000, Total Reward: -10495.5
# Episode: 25000, Total Reward: -10932.0
# Episode: 26000, Total Reward: -11358.5
# Episode: 27000, Total Reward: -11789.5
# Episode: 28000, Total Reward: -12221.5
# Episode: 29000, Total Reward: -12652.0
# Episode: 30000, Total Reward: -13088.5
# Episode: 31000, Total Reward: -13524.5
# Episode: 32000, Total Reward: -13952.0
# Episode: 33000, Total Reward: -14390.5
# Episode: 34000, Total Reward: -14825.0
# Episode: 35000, Total Reward: -15262.0
# Episode: 36000, Total Reward: -15691.0
# Episode: 37000, Total Reward: -16128.5
# Episode: 38000, Total Reward: -16571.0
# Episode: 39000, Total Reward: -17001.5
# Episode: 40000, Total Reward: -17434.5
# Episode: 41000, Total Reward: -17867.0
# Episode: 42000, Total Reward: -18306.0
# Episode: 43000, Total Reward: -18740.5
# Episode: 44000, Total Reward: -19174.5
# Episode: 45000, Total Reward: -19618.5
# Episode: 46000, Total Reward: -20047.5
# Episode: 47000, Total Reward: -20479.5
# Episode: 48000, Total Reward: -20902.5
# Episode: 49000, Total Reward: -21336.5
# Episode: 50000, Total Reward: -21754.5
# Episode: 483000, Total Reward: -210659.0
# Episode: 484000, Total Reward: -211095.5
# Episode: 485000, Total Reward: -211537.0
# Episode: 486000, Total Reward: -211973.0
# Episode: 487000, Total Reward: -212415.5
# Episode: 488000, Total Reward: -212845.0
# Episode: 489000, Total Reward: -213287.5
# Episode: 490000, Total Reward: -213729.0
# Episode: 491000, Total Reward: -214166.0
# Episode: 492000, Total Reward: -214600.5
# Episode: 493000, Total Reward: -215036.0
# Episode: 494000, Total Reward: -215463.0
# Episode: 495000, Total Reward: -215911.5
# Episode: 496000, Total Reward: -216345.5
# Episode: 497000, Total Reward: -216783.5
# Episode: 498000, Total Reward: -217225.5
# Episode: 499000, Total Reward: -217663.0
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' '.']]
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' 'X']]
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['O' '.' 'X']]
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['O' 'X' 'X']]
# Current State:
# [['.' '.' 'O']
#  ['.' '.' '.']
#  ['O' 'X' 'X']]
# Current State:
# [['X' '.' 'O']
#  ['.' '.' '.']
#  ['O' 'X' 'X']]
# Current State:
# [['X' '.' 'O']
#  ['.' '.' 'O']
#  ['O' 'X' 'X']]
# Game Over. Winner: X
# [['X' '.' 'O']
#  ['.' 'X' 'O']
#  ['O' 'X' 'X']]
#  - - - - - - - - - - -
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' '.']]
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' 'X']]
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['O' '.' 'X']]
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['O' 'X' 'X']]
# Current State:
# [['.' 'O' '.']
#  ['.' '.' '.']
#  ['O' 'X' 'X']]
# Current State:
# [['.' 'O' '.']
#  ['.' 'X' '.']
#  ['O' 'X' 'X']]
# Current State:
# [['O' 'O' '.']
#  ['.' 'X' '.']
#  ['O' 'X' 'X']]
# Current State:
# [['O' 'O' '.']
#  ['X' 'X' '.']
#  ['O' 'X' 'X']]
# Game Over. Winner: O
# [['O' 'O' 'O']
#  ['X' 'X' '.']
#  ['O' 'X' 'X']]
#  - - - - - - - - - - -
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' '.']]
# Current State:
# [['.' '.' '.']
#  ['X' '.' '.']
#  ['.' '.' '.']]
# Current State:
# [['.' '.' 'O']
#  ['X' '.' '.']
#  ['.' '.' '.']]
# Current State:
# [['.' '.' 'O']
#  ['X' '.' 'X']
#  ['.' '.' '.']]
# Current State:
# [['.' '.' 'O']
#  ['X' 'O' 'X']
#  ['.' '.' '.']]
# Current State:
# [['.' '.' 'O']
#  ['X' 'O' 'X']
#  ['.' 'X' '.']]
# Current State:
# [['O' '.' 'O']
#  ['X' 'O' 'X']
#  ['.' 'X' '.']]
# Current State:
# [['O' 'X' 'O']
#  ['X' 'O' 'X']
#  ['.' 'X' '.']]
# Game Over. Winner: O
# [['O' 'X' 'O']
#  ['X' 'O' 'X']
#  ['O' 'X' '.']]
#  - - - - - - - - - - -
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' '.']]
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' 'X']]
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' 'O' 'X']]
# Current State:
# [['.' 'X' '.']
#  ['.' '.' '.']
#  ['.' 'O' 'X']]
# Current State:
# [['.' 'X' '.']
#  ['O' '.' '.']
#  ['.' 'O' 'X']]
# Current State:
# [['.' 'X' '.']
#  ['O' '.' 'X']
#  ['.' 'O' 'X']]
# Current State:
# [['.' 'X' 'O']
#  ['O' '.' 'X']
#  ['.' 'O' 'X']]
# Current State:
# [['X' 'X' 'O']
#  ['O' '.' 'X']
#  ['.' 'O' 'X']]
# Current State:
# [['X' 'X' 'O']
#  ['O' 'O' 'X']
#  ['.' 'O' 'X']]
# Game Over. Winner: None
# [['X' 'X' 'O']
#  ['O' 'O' 'X']
#  ['X' 'O' 'X']]
#  - - - - - - - - - - -
# Current State:
# [['.' '.' '.']
#  ['.' '.' '.']
#  ['.' '.' '.']]
# Current State:
# [['.' '.' '.']
#  ['.' 'X' '.']
#  ['.' '.' '.']]
# Current State:
# [['.' 'O' '.']
#  ['.' 'X' '.']
#  ['.' '.' '.']]
# Current State:
# [['.' 'O' '.']
#  ['.' 'X' '.']
#  ['.' '.' 'X']]
# Current State:
# [['.' 'O' '.']
#  ['.' 'X' '.']
#  ['.' 'O' 'X']]
# Current State:
# [['.' 'O' '.']
#  ['.' 'X' 'X']
#  ['.' 'O' 'X']]
# Current State:
# [['.' 'O' '.']
#  ['.' 'X' 'X']
#  ['O' 'O' 'X']]
# Game Over. Winner: X
# [['.' 'O' '.']
#  ['X' 'X' 'X']
#  ['O' 'O' 'X']]
#  - - - - - - - - - - -
